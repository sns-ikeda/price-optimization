# %%
import sys
from pathlib import Path
sys.path.append(str(Path().cwd().parent))

from tqdm import tqdm
import time

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
NUM_ITERATION = 1
SOLVER = "DEFAULT"

m_sizes = [5, 10, 14]
result_calc_time = dict()

# %%
K = 5
for m_size in tqdm(m_sizes):
    start = time.time()
    for m in tqdm(range(K**m_size)):
        pass
    elapsed_time = (time.time() - start)/60
    print(f"m_size: {m_size}, calc_time: {elapsed_time} ")
# Out:
# 100%|██████████| 3125/3125 [00:00<00:00, 3926662.67it/s]
# m_size: 5, calc_time: 0.00012948115666707358
# ...
#  67%|██████▋   | 2/3 [00:01<00:00,  1.23it/s]
# m_size: 10, calc_time: 0.027012852827707927
# ...
# 100%|██████████| 3/3 [17:02<00:00, 340.81s/it]
# m_size: 14, calc_time: 17.01314982175827

# %%
17.01314982175827 * 60 * 5
# Out:
# 5103.94494652748

# %%
plt.style.use('default')
sns.set()
sns.set_style('whitegrid')
sns.set_palette('gray')

x = np.array([5, 10, 15])
y = np.array([2.197424570719401e-06, 0.004916497071584066, 5103.94494652748])
e = np.array([0.8, 0.9, 0.5, 1.1])

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.plot(x, y, marker='.',markersize=10)
# ax.errorbar(x, y, yerr=e, marker='o', capthick=1, capsize=10, lw=1)

ax.set_xlabel("M: number of products")
ax.set_ylabel("computational time [s]")
# ax.set_ylim(0, 20)
ax.set_xticks([5, 10, 15])
# ax.set_xlim(5, 20)

plt.show()
